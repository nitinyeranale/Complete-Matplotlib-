# %% [markdown]
# ## Histrogram Plot ------------------------

# %%
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
x=np.random.randint(10,60,(50))
print(x)
# Out:
# [25 51 24 22 38 58 12 41 55 49 32 59 59 28 45 46 16 50 27 33 27 21 27 27
#  12 52 23 56 36 55 17 32 44 57 28 23 30 21 13 45 35 55 41 20 25 38 11 37
#  44 47]

# %%
no=[25, 51, 24, 22, 38, 58, 12, 41, 55, 49, 32, 59, 59, 28, 45, 46, 16, 50, 27, 33, 27, 21, 27, 27,
 12, 52, 23, 56, 36, 55, 17, 32, 44, 57, 28, 23, 30, 21, 13, 45, 35, 55, 41, 20, 25, 38, 11, 37,
 44, 47]
l=[10,20,30,40,50,60]
plt.title("Histogram")
plt.xlabel("Python")
plt.ylabel("No")
plt.hist(no,edgecolor="g",color="r ",bins=l)
plt.show()

# %%
no=[25, 51, 24, 22, 38, 58, 12, 41, 55, 49, 32, 59, 59, 28, 45, 46, 16, 50, 27, 33, 27, 21, 27, 27,
 12, 52, 23, 56, 36, 55, 17, 32, 44, 57, 28, 23, 30, 21, 13, 45, 35, 55, 41, 20, 25, 38, 11, 37,
 44, 47]

plt.hist(no,cumulative=-1,edgecolor="g",bottom=5 ,align="right",histtype="barstacked", orientation="vertical", rwidth=0.8, label="Python",density=False)
plt.legend()
plt.show()
