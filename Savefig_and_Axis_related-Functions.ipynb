# %% [markdown]
# ### Savefig -------------------------

# %%
import matplotlib.pyplot as plt

x=[23,56,56,87]
plt.pie(x)

plt.savefig("Pie_Plot1",dpi=2000)

plt.show()

# %%
x=[1,2,3,4,5]
y=[3,1,5,2,4]

plt.plot(x,y)

# plt.xticks(x)
# plt.yticks(x)

# plt.xticks(x,labels=["Python","Java","C","C++","R"])
# plt.yticks(x,labels=["A","B","C","D","E"])

# plt.xlim(0,10)
# plt.ylim(1,5)

plt.axis([0,7,-1,8])

plt.show()
